# %%
import matplotlib.pyplot as plt
import cv2
img=cv2.imread("modi.webp")
img=cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
blurred_img1=cv2.blur(img,(10,10))
blurred_img2=cv2.GaussianBlur(img,(5,5),0)
blurred_img3=cv2.medianBlur(img,3)
plt.subplot(2,2,1),plt.imshow(img),plt.title("original image")
plt.subplot(2,2,2),plt.imshow(blurred_img1),plt.title("box blur")
plt.subplot(2,2,3),plt.imshow(blurred_img2),plt.title("gussian blur")
plt.subplot(2,2,4),plt.imshow(blurred_img3),plt.title("median blur")
# Out:
# (<AxesSubplot:title={'center':'median blur'}>,
#  <matplotlib.image.AxesImage at 0x158fffa6d60>,
#  Text(0.5, 1.0, 'median blur'))

# %%
import numpy as np
img=cv2.imread("modi.webp")
img=cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
k1=np.ones((8,8))/64
k1=np.ones((8,8),np.float32)/64
print(k1)
blurred_img=cv2.filter2D(img,-1,k1)
plt.imshow(blurred_img)
# Out:
# [[0.015625 0.015625 0.015625 0.015625 0.015625 0.015625 0.015625 0.015625]
#  [0.015625 0.015625 0.015625 0.015625 0.015625 0.015625 0.015625 0.015625]
#  [0.015625 0.015625 0.015625 0.015625 0.015625 0.015625 0.015625 0.015625]
#  [0.015625 0.015625 0.015625 0.015625 0.015625 0.015625 0.015625 0.015625]
#  [0.015625 0.015625 0.015625 0.015625 0.015625 0.015625 0.015625 0.015625]
#  [0.015625 0.015625 0.015625 0.015625 0.015625 0.015625 0.015625 0.015625]
#  [0.015625 0.015625 0.015625 0.015625 0.015625 0.015625 0.015625 0.015625]
#  [0.015625 0.015625 0.015625 0.015625 0.015625 0.015625 0.015625 0.015625]]
